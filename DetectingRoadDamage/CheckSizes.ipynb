# %%
import os
from tqdm.auto import tqdm
from glob import glob
from PIL import Image, ImageDraw # draw on images
from IPython.display import display # display images on jupyter notebook
import numpy as np

# %%
input_dir = "F:/RoadDamageDetection/Datasets/RDD2022"
countries = ["China_Drone","China_MotorBike", "Czech", "India", "Japan", "Norway", "United_States"]

# %% [markdown]
# # Check Image Sizes

# %%
def get_sizes(input_dir, c):
    input_train_images = os.path.join(input_dir,c, "train/images")
    files = glob(os.path.join(input_train_images, "*.jpg"))
    widths = set()
    heights = set() 
    for f in tqdm(files):
        img = Image.open(f)
        w, h = img.size
        widths.add(w)
        heights.add(h)
    return widths, heights

# %%
for c in countries:
    print(f'{c}: {get_sizes(input_dir, c)}')
# Out:
#   0%|          | 0/482 [00:00<?, ?it/s]
# China_Drone: ({512}, {512})
#   0%|          | 0/43 [00:00<?, ?it/s]
# China_MotorBike: ({512}, {512})
#   0%|          | 0/1757 [00:00<?, ?it/s]
# Czech: ({600}, {600})
#   0%|          | 0/4483 [00:00<?, ?it/s]
# India: ({720}, {720})
#   0%|          | 0/2606 [00:00<?, ?it/s]
# Japan: ({600, 1080}, {600, 1080})
#   0%|          | 0/5247 [00:00<?, ?it/s]
# Norway: ({4040, 3650, 3643}, {2041, 2035, 2044})
# 0it [00:00, ?it/s]
# United_States: (set(), set())

# %%
# for Japan check if they are squared
input_train_images = os.path.join(input_dir,"Japan", "train/images")
files = glob(os.path.join(input_train_images, "*.jpg"))
not_squared = 0
for f in tqdm(files):
    img = Image.open(f)
    w, h = img.size
    if w!=h:
        not_squared += 1
print(not_squared)
# Out:
#   0%|          | 0/2606 [00:00<?, ?it/s]
# 0

# %%
input_dir = "RDD2022_1"

# %%
def get_sizes(input_dir, c):
    input_train_images = os.path.join(input_dir,c, "images/train")
    files = glob(os.path.join(input_train_images, "*.jpg"))
    widths = set()
    heights = set() 
    for f in tqdm(files):
        img = Image.open(f)
        w, h = img.size
        widths.add(w)
        heights.add(h)
    return widths, heights

# %%
for c in countries:
    print(f'{c}: {get_sizes(input_dir, c)}')
# Out:
# 0it [00:00, ?it/s]
# China_Drone: (set(), set())
# 0it [00:00, ?it/s]
# China_MotorBike: (set(), set())
# 0it [00:00, ?it/s]
# Czech: (set(), set())
# 0it [00:00, ?it/s]
# India: (set(), set())
# 0it [00:00, ?it/s]
# Japan: (set(), set())
# 0it [00:00, ?it/s]
# Norway: (set(), set())
# 0it [00:00, ?it/s]
# United_States: (set(), set())
# 0it [00:00, ?it/s]
# Norway1: (set(), set())

# %%
import xml.etree.ElementTree as ET # parse xml anotation

# %%
# check for image sizes and those inside the XML file
def check_sizes(input_dir, c):
    input_train_images = os.path.join(input_dir,c, "train/images")
    files = glob(os.path.join(input_train_images, "*.jpg"))
    
    for f in tqdm(files):
        img = Image.open(f)
        w, h = img.size
        fil = os.path.join(input_dir, c, "train/annotations/xmls", os.path.splitext(os.path.basename(f))[0] + ".xml")
        tree = ET.parse(fil)
        root = tree.getroot()
        width = int(root.find("size").find("width").text)
        height = int(root.find("size").find("height").text)
        if width != w or height != h:
            print(os.path.basename(f))

# %%
for c in countries:
    check_sizes(input_dir, c)
# Out:
#   0%|          | 0/482 [00:00<?, ?it/s]
#   0%|          | 0/43 [00:00<?, ?it/s]
#   0%|          | 0/1757 [00:00<?, ?it/s]
#   0%|          | 0/4483 [00:00<?, ?it/s]
#   0%|          | 0/2606 [00:00<?, ?it/s]
#   0%|          | 0/5247 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]

# %%
def get_sizes(input_dir, c):
    from pathlib import Path
    image_dir = Path(input_dir) / c / "train" / "images"
    image_files = list(image_dir.glob("*.jpg"))
    print(f"{c}: Found {len(image_files)} images in {image_dir}")
    widths, heights = set(), set()
    for file in tqdm(image_files):
        img = Image.open(file)
        w, h = img.size
        widths.add(w)
        heights.add(h)
    return widths, heights

# %%
input_dir = "F:/RoadDamageDetection/Datasets/RDD2022"

# %%
get_sizes(input_dir, "India")
# Out:
# India: Found 4483 images in F:\RoadDamageDetection\Datasets\RDD2022\India\train\images
#   0%|          | 0/4483 [00:00<?, ?it/s]
# ({720}, {720})
